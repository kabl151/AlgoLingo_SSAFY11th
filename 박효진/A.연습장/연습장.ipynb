# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 from collections import deque
# ----> 3 T = int(input())
#       5 for tc in range(1, T+1):
#       6     N, M = map(int, input().split())
#
# ValueError: invalid literal for int() with base 10: ''
